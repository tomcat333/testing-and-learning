# %%
import itchat,time
# Out:
# █

# %%
itchat.auto_login(hotReload=True)
# Out:
# Please press confirm on your phone.
# Log in time out, reloading QR code.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as 脸盲

# %%
def lgin():
    print("finished login!")
def lgot():
    print("logged out!")
    
itchat.auto_login(loginCallback=lgin,exitCallback=lgot)
time.sleep(1)
itchat.logout()
# Out:
# itchat has already logged in.
# <ItchatReturnValue: {'BaseResponse': {'ErrMsg': '请求成功', 'Ret': 0, 'RawMsg': 'logout successfully.'}}>

# %%
itchat.send(msg="张民子最厉害！")
itchat.run()
# Out:
# Start auto replying.
# Bye~

# %%
itchat.send('Hello, filehelper', toUserName='filehelper')
# Out:
# <ItchatReturnValue: {'BaseResponse': {'Ret': 0, 'ErrMsg': '请求成功', 'RawMsg': '请求成功'}, 'MsgID': '8062476883044716443', 'LocalID': '15236987144013'}>
# LOG OUT!

# %%
itchat.send_image(r'F:\照片\2013年3月12 所里\IMG_20130112_123254.jpg',toUserName='filehelper')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-f66024ce700d> in <module>()
# ----> 1 itchat.send_image(r'F:\照片\2013年3月12 所里\IMG_20130112_123254.jpg',toUserName='filehelper')
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\itchat\components\messages.py in send_image(self, fileDir, toUserName, mediaId, file_)
#     417         toUserName = self.storageClass.userName
#     418     if mediaId is None:
# --> 419         r = self.upload_file(fileDir, isPicture=not fileDir[-4:] == '.gif', file_=file_)
#     420         if r:
#     421             mediaId = r['MediaId']
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\itchat\components\messages.py in upload_file(self, fileDir, isPicture, isVideo, toUserName, file_, preparedFile)
#     329     for chunk in range(chunks):
# ...

# %%
itchat.send("@img@%s" % r'F:\照片\2013年3月12 所里\IMG_20130112_123254.jpg',toUserName='filehelper')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-85441ae8a07c> in <module>()
# ----> 1 itchat.send("@img@%s" % r'F:\照片\2013年3月12 所里\IMG_20130112_123254.jpg',toUserName='filehelper')
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\itchat\components\messages.py in send(self, msg, toUserName, mediaId)
#     495     elif msg[:5] == '@img@':
#     496         if mediaId is None:
# --> 497             r = self.send_image(msg[5:], toUserName)
#     498         else:
#     499             r = self.send_image(msg[5:], toUserName, mediaId)
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\itchat\components\messages.py in send_image(self, fileDir, toUserName, mediaId, file_)
#     417         toUserName = self.storageClass.userName
#     418     if mediaId is None:
# ...

# %%
itchat.send_msg("hello world",toUserName=account[0]['UserName'])
# Out:
# <ItchatReturnValue: {'BaseResponse': {'Ret': 1204, 'ErrMsg': '', 'RawMsg': ''}, 'MsgID': '', 'LocalID': ''}>

# %%
account=itchat.search_friends(name='妞子')

# %%
account[0]['UserName']
# Out:
# '@f7fdfa6a92a792b2c2ee714801e86f3d567e0a80e28677cfb563e85a4b62406c'

# %%
addc=itchat.get_mps()

# %%
addc
# Out:
# <ContactList: []>

# %%
print(account)
# Out:
# [<User: {'MemberList': <ContactList: []>, 'UserName': '@b0b3a931a0f2c1fd366eeb50968e40c2', 'City': '', 'DisplayName': '', 'PYQuanPin': '', 'RemarkPYInitial': '', 'Province': '', 'KeyWord': '', 'RemarkName': '', 'PYInitial': '', 'EncryChatRoomId': '', 'Alias': '', 'Signature': '重度面盲，求理解', 'NickName': '脸盲', 'RemarkPYQuanPin': '', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=886144067&username=@b0b3a931a0f2c1fd366eeb50968e40c2&skey=@crypt_4b179e66_17e5641c1ff5d47c6b15d5b841f1621c', 'UniFriend': 0, 'Sex': 1, 'AppAccountFlag': 0, 'VerifyFlag': 0, 'ChatRoomId': 0, 'HideInputBarFlag': 0, 'AttrStatus': 0, 'SnsFlag': 17, 'MemberCount': 0, 'OwnerUin': 0, 'ContactFlag': 0, 'Uin': 1381982260, 'StarFriend': 0, 'Statues': 0, 'WebWxPluginSwitch': 0, 'HeadImgFlag': 1}>, <User: {'MemberList': <ContactList: []>, 'Uin': 0, 'UserName': '@876d23b2c5800cc2243971aee64e512b39ef788b865e6f13be7bc7b16cdbc36e', 'NickName': '帝后', 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=650038747&username=@87
# ...

# %%
for i in range(100):
    msg="张婆子亲我"+str(i+1)+"口"
    itchat.send(msg, toUserName='@f7fdfa6a92a792b2c2ee714801e86f3d567e0a80e28677cfb563e85a4b62406c')
