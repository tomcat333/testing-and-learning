# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
s=pd.Series([1,3,6,np.nan])
s
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# dtype: float64

# %%
s[3]
# Out:
# nan

# %%
dates=pd.date_range("20170101",periods=6)
dates
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.rand(6,4),index=dates_3,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.544293  0.422328  0.090608  0.830838
# 1  0.162294  0.175517  0.035722  0.728938
# 2  0.257009  0.922273  0.653803  0.381953
# 3  0.615261  0.934599  0.057223  0.661797
# 4  0.876807  0.633734  0.765457  0.019617
# 5  0.120456  0.356086  0.537047  0.273419

# %%
dates_2=np.array(range(6))
dates_2
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
dates_3=list(range(6))
dates_3
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
df=pd.read_csv("uk_rain_2014.csv",header=0)
df
# Out:
#    Water Year  Rain (mm) Oct-Sep  Outflow (m3/s) Oct-Sep  Rain (mm) Dec-Feb  \
# 0     1980/81               1182                    5408                292
# 1     1981/82               1098                    5112                257
# 2     1982/83               1156                    5701                330
# 3     1983/84                993                    4265                391
# 4     1984/85               1182                    5364                217
# 5     1985/86               1027                    4991                304
# 6     1986/87               1151                    5196                295
# 7     1987/88               1210                    5572                343
# 8     1988/89                976                    4330                309
# 9     1989/90               1130                    4973                470
# 10    1990/91               1022                    4418                305
# ...

# %%
df.head(5)
# Out:
#   Water Year  Rain (mm) Oct-Sep  Outflow (m3/s) Oct-Sep  Rain (mm) Dec-Feb  \
# 0    1980/81               1182                    5408                292
# 1    1981/82               1098                    5112                257
# 2    1982/83               1156                    5701                330
# 3    1983/84                993                    4265                391
# 4    1984/85               1182                    5364                217
#
#    Outflow (m3/s) Dec-Feb  Rain (mm) Jun-Aug  Outflow (m3/s) Jun-Aug
# 0                    7248                174                    2212
# 1                    7316                242                    1936
# 2                    8567                124                    1802
# 3                    8905                141                    1078
# 4                    5813                343                    4313

# %%
df.tail(5)
# Out:
#    Water Year  Rain (mm) Oct-Sep  Outflow (m3/s) Oct-Sep  Rain (mm) Dec-Feb  \
# 28    2008/09               1139                    4941                268
# 29    2009/10               1103                    4738                255
# 30    2010/11               1053                    4521                265
# 31    2011/12               1285                    5500                339
# 32    2012/13               1090                    5329                350
#
#     Outflow (m3/s) Dec-Feb  Rain (mm) Jun-Aug  Outflow (m3/s) Jun-Aug
# 28                    6690                323                    3189
# 29                    6435                244                    1958
# 30                    6593                267                    2885
# 31                    7630                379                    5261
# 32                    9615                187                    1797

# %%
df.columns=["year","rain_mm109","outflow_ms109","rain_mm122","outflow_ms122","rain_mm18","outflow_ms18"]

# %%
df
# Out:
#        year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 0   1980/81        1182           5408         292           7248        174
# 1   1981/82        1098           5112         257           7316        242
# 2   1982/83        1156           5701         330           8567        124
# 3   1983/84         993           4265         391           8905        141
# 4   1984/85        1182           5364         217           5813        343
# 5   1985/86        1027           4991         304           7951        229
# 6   1986/87        1151           5196         295           7593        267
# 7   1987/88        1210           5572         343           8456        294
# 8   1988/89         976           4330         309           6465        200
# 9   1989/90        1130           4973         470          10520        209
# 10  1990/91        1022           4418         305           7120        216
# ...

# %%
len(df)
# Out:
# 33

# %%
df.describe()
# Out:
#         rain_mm109  outflow_ms109  rain_mm122  outflow_ms122   rain_mm18  \
# count    33.000000      33.000000   33.000000      33.000000   33.000000
# mean   1129.000000    5019.181818  325.363636    7926.545455  237.484848
# std     101.900074     658.587762   69.995008    1692.800049   66.167931
# min     856.000000    3479.000000  206.000000    4578.000000  103.000000
# 25%    1053.000000    4506.000000  268.000000    6690.000000  193.000000
# 50%    1139.000000    5112.000000  309.000000    7630.000000  229.000000
# 75%    1182.000000    5497.000000  360.000000    8905.000000  280.000000
# max    1387.000000    6391.000000  484.000000   11486.000000  379.000000
#
#        outflow_ms18
# count     33.000000
# mean    2439.757576
# std     1025.914106
# min     1078.000000
# 25%     1797.000000
# 50%     2142.000000
# 75%     2959.000000
# max     5261.000000

# %%
df["rain_mm122"]
# Out:
# 0     292
# 1     257
# 2     330
# 3     391
# 4     217
# 5     304
# 6     295
# 7     343
# 8     309
# 9     470
# 10    305
# 11    246
# 12    308
# 13    422
# 14    484
# 15    245
# 16    258
# 17    341
# 18    360
# 19    417
# 20    328
# 21    380
# 22    272
# 23    348
# 24    309
# 25    206
# 26    437
# 27    386
# 28    268
# 29    255
# 30    265
# 31    339
# 32    350
# Name: rain_mm122, dtype: int64

# %%
df.rain_mm122
# Out:
# 0     292
# 1     257
# 2     330
# 3     391
# 4     217
# 5     304
# 6     295
# 7     343
# 8     309
# 9     470
# 10    305
# 11    246
# 12    308
# 13    422
# 14    484
# 15    245
# 16    258
# 17    341
# 18    360
# 19    417
# 20    328
# 21    380
# 22    272
# 23    348
# 24    309
# 25    206
# 26    437
# 27    386
# 28    268
# 29    255
# 30    265
# 31    339
# 32    350
# Name: rain_mm122, dtype: int64

# %%
df[df.rain_mm109<1000]
# Out:
#        year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 3   1983/84         993           4265         391           8905        141
# 8   1988/89         976           4330         309           6465        200
# 15  1995/96         856           3479         245           5515        172
#
#     outflow_ms18
# 3           1078
# 8           1440
# 15          1439

# %%
df.iloc[3]
# Out:
# year             1983/84
# rain_mm109           993
# outflow_ms109       4265
# rain_mm122           391
# outflow_ms122       8905
# rain_mm18            141
# outflow_ms18        1078
# Name: 3, dtype: object

# %%
df.iloc[3]["rain_mm18"]
# Out:
# 141

# %%
df.loc[3]
# Out:
# year             1983/84
# rain_mm109           993
# outflow_ms109       4265
# rain_mm122           391
# outflow_ms122       8905
# rain_mm18            141
# outflow_ms18        1078
# Name: 3, dtype: object

# %%
type(df.loc[3])
# Out:
# pandas.core.series.Series

# %%
df[df.year.str.startswith("199")]
# Out:
#        year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 10  1990/91        1022           4418         305           7120        216
# 11  1991/92        1151           4506         246           5493        280
# 12  1992/93        1130           5246         308           8751        219
# 13  1993/94        1162           5583         422          10109        193
# 14  1994/95        1110           5370         484          11486        103
# 15  1995/96         856           3479         245           5515        172
# 16  1996/97        1047           4019         258           5770        256
# 17  1997/98        1169           4953         341           7747        285
# 18  1998/99        1268           5824         360           8771        225
# 19  1999/00        1204           5665         417          10021        197
#
#     outflow_ms18
# 10          1923
# 11          2118
# 12          2551
# 13          1638
# 14          1231
# ...

# %%
df.year.str.startswith("199")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# Name: year, dtype: bool

# %%
df.year.str.endswith("00")
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# Name: year, dtype: bool

# %%
df.loc[3].str.startswith("1")
# Out:
# year             True
# rain_mm109        NaN
# outflow_ms109     NaN
# rain_mm122        NaN
# outflow_ms122     NaN
# rain_mm18         NaN
# outflow_ms18      NaN
# Name: 3, dtype: object

# %%
df.iloc[3].str.startswith('1')
# Out:
# year             True
# rain_mm109        NaN
# outflow_ms109     NaN
# rain_mm122        NaN
# outflow_ms122     NaN
# rain_mm18         NaN
# outflow_ms18      NaN
# Name: 3, dtype: object

# %%
df.iloc[3].str.isnumeric()
# Out:
# year             False
# rain_mm109         NaN
# outflow_ms109      NaN
# rain_mm122         NaN
# outflow_ms122      NaN
# rain_mm18          NaN
# outflow_ms18       NaN
# Name: 3, dtype: object

# %%
df.set_index(['year'])
# Out:
#          rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# year
# 1980/81        1182           5408         292           7248        174
# 1981/82        1098           5112         257           7316        242
# 1982/83        1156           5701         330           8567        124
# 1983/84         993           4265         391           8905        141
# 1984/85        1182           5364         217           5813        343
# 1985/86        1027           4991         304           7951        229
# 1986/87        1151           5196         295           7593        267
# 1987/88        1210           5572         343           8456        294
# 1988/89         976           4330         309           6465        200
# 1989/90        1130           4973         470          10520        209
# 1990/91        1022           4418         305           7120        216
# 1991/92        1151           4506         246           5493        280
# ...

# %%
df.head(5)
# Out:
#       year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 0  1980/81        1182           5408         292           7248        174
# 1  1981/82        1098           5112         257           7316        242
# 2  1982/83        1156           5701         330           8567        124
# 3  1983/84         993           4265         391           8905        141
# 4  1984/85        1182           5364         217           5813        343
#
#    outflow_ms18
# 0          2212
# 1          1936
# 2          1802
# 3          1078
# 4          4313

# %%
def base_year(year):
    base_year=year[:4]
    base_year=pd.to_datetime(base_year).year
    return base_year
df['year_2']=df.year.apply(base_year)

# %%
df.head(5)
# Out:
#       year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 0  1980/81        1182           5408         292           7248        174
# 1  1981/82        1098           5112         257           7316        242
# 2  1982/83        1156           5701         330           8567        124
# 3  1983/84         993           4265         391           8905        141
# 4  1984/85        1182           5364         217           5813        343
#
#    outflow_ms18  year_2
# 0          2212    1980
# 1          1936    1981
# 2          1802    1982
# 3          1078    1983
# 4          4313    1984

# %%
A=df.groupby(df['year_2']//10*10).max()

# %%
A
# Out:
#            year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  \
# year_2
# 1980    1989/90        1210           5701         470          10520
# 1990    1999/00        1268           5824         484          11486
# 2000    2009/10        1387           6391         437          10926
# 2010    2012/13        1285           5500         350           9615
#
#         rain_mm18  outflow_ms18  year_2
# year_2
# 1980          343          4313    1989
# 1990          285          3206    1999
# 2000          357          5168    2009
# 2010          379          5261    2012

# %%
B=df.groupby([df.year_2//10*10,df.rain_mm109//1000*1000])[['outflow_ms109','rain_mm122','outflow_ms18']].mean()

# %%
B
# Out:
#                    outflow_ms109  rain_mm122  outflow_ms18
# year_2 rain_mm109
# 1980   0             4297.500000       350.0   1259.000000
#        1000          5289.625000       313.5   2572.250000
# 1990   0             3479.000000       245.0   1439.000000
#        1000          5064.888889       349.0   2130.555556
# 2000   1000          5030.800000       318.9   2685.900000
# 2010   1000          5116.666667       318.0   3314.333333

# %%
B.unstack(0)
# Out:
#            outflow_ms109                                   rain_mm122         \
# year_2              1980         1990    2000         2010       1980   1990
# rain_mm109
# 0               4297.500  3479.000000     NaN          NaN      350.0  245.0
# 1000            5289.625  5064.888889  5030.8  5116.666667      313.5  349.0
#
#                          outflow_ms18
# year_2       2000   2010         1980         1990    2000         2010
# rain_mm109
# 0             NaN    NaN      1259.00  1439.000000     NaN          NaN
# 1000        318.9  318.0      2572.25  2130.555556  2685.9  3314.333333

# %%
B.unstack(1)
# Out:
#            outflow_ms109              rain_mm122        outflow_ms18  \
# rain_mm109          0            1000       0      1000         0
# year_2
# 1980              4297.5  5289.625000      350.0  313.5       1259.0
# 1990              3479.0  5064.888889      245.0  349.0       1439.0
# 2000                 NaN  5030.800000        NaN  318.9          NaN
# 2010                 NaN  5116.666667        NaN  318.0          NaN
#
#
# rain_mm109         1000
# year_2
# 1980        2572.250000
# 1990        2130.555556
# 2000        2685.900000
# 2010        3314.333333

# %%
high_rain=df[df.rain_mm109>1250]
high_rain
# Out:
#        year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 18  1998/99        1268           5824         360           8771        225
# 26  2006/07        1387           6391         437          10926        357
# 31  2011/12        1285           5500         339           7630        379
#
#     outflow_ms18  year_2
# 18          2240    1998
# 26          5168    2006
# 31          5261    2011

# %%
high_rain.pivot('year_2','rain_mm109')[['outflow_ms109','rain_mm122','outflow_ms18']].fillna('')
# Out:
#            outflow_ms109             rain_mm122           outflow_ms18        \
# rain_mm109          1268  1285  1387       1268 1285 1387         1268  1285
# year_2
# 1998                5824                    360                   2240
# 2006                            6391                  437
# 2011                      5500                   339                    5261
#
#
# rain_mm109  1387
# year_2
# 1998
# 2006        5168
# 2011

# %%
jp_year=pd.date_range(start="1980-01-01",periods=5,freq="1Y").year
jp_year
# Out:
# Int64Index([1980, 1981, 1982, 1983, 1984], dtype='int64')

# %%
jp_rainfall=[1558,1464,1576,1341,880]

# %%
rain_jpn=pd.DataFrame(jp_rainfall,columns=["jpn_rainfall"])
rain_jpn
# Out:
#    jpn_rainfall
# 0          1558
# 1          1464
# 2          1576
# 3          1341
# 4           880

# %%
rain_jpn['year']=jp_year
rain_jpn
# Out:
#    jpn_rainfall  year
# 0          1558  1980
# 1          1464  1981
# 2          1576  1982
# 3          1341  1983
# 4           880  1984

# %%
df.columns=['water_year', 'rain_mm109', 'outflow_ms109', 'rain_mm122', 'outflow_ms122',
       'rain_mm18', 'outflow_ms18', 'year_2']

# %%
df.rename(columns={df.columns[7]:"year"},inplace="true")

# %%
uk_jpn_rainfall=df.merge(rain_jpn,on='year')

# %%
uk_jpn_rainfall
# Out:
#   water_year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  rain_mm18  \
# 0    1980/81        1182           5408         292           7248        174
# 1    1981/82        1098           5112         257           7316        242
# 2    1982/83        1156           5701         330           8567        124
# 3    1983/84         993           4265         391           8905        141
# 4    1984/85        1182           5364         217           5813        343
#
#    outflow_ms18  year  jpn_rainfall
# 0          2212  1980          1558
# 1          1936  1981          1464
# 2          1802  1982          1576
# 3          1078  1983          1341
# 4          4313  1984           880

# %%
uk_jpn_rainfall.plot(x="year",y=['rain_mm109','jpn_rainfall'])
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
df.to_csv('uk_rain.csv')

# %%
df2=pd.read_excel("uk_rain.xlsx")

# %%
df2
# Out:
#              water_year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  \
# 0               1980/81        1182           5408         292           7248
# 1               1981/82        1098           5112         257           7316
# 2               1982/83        1156           5701         330           8567
# 3               1983/84         993           4265         391           8905
# 4               1984/85        1182           5364         217           5813
# 5               1985/86        1027           4991         304           7951
# 6               1986/87        1151           5196         295           7593
# 7               1987/88        1210           5572         343           8456
# 8               1988/89         976           4330         309           6465
# 9               1989/90        1130           4973         470          10520
# 10              1990/91        1022           4418         305           7120
# ...

# %%
def mul100(num):
    mul100=100*num
    return mul100

# %%
df['rain_mm122']=df2.rain_mm122.apply(mul100)

# %%
df
# Out:
#    water_year  rain_mm109  outflow_ms109  rain_mm122  outflow_ms122  \
# 0     1980/81        1182           5408       29200           7248
# 1     1981/82        1098           5112       25700           7316
# 2     1982/83        1156           5701       33000           8567
# 3     1983/84         993           4265       39100           8905
# 4     1984/85        1182           5364       21700           5813
# 5     1985/86        1027           4991       30400           7951
# 6     1986/87        1151           5196       29500           7593
# 7     1987/88        1210           5572       34300           8456
# 8     1988/89         976           4330       30900           6465
# 9     1989/90        1130           4973       47000          10520
# 10    1990/91        1022           4418       30500           7120
# 11    1991/92        1151           4506       24600           5493
# 12    1992/93        1130           5246       30800           8751
# ...

# %%
df.columns
# Out:
# Index(['water_year', 'rain_mm109', 'outflow_ms109', 'rain_mm122',
#        'outflow_ms122', 'rain_mm18', 'outflow_ms18', 'year', 'whos'],
#       dtype='object')

# %%
df3=df[['water_year', 'rain_mm109', 'outflow_ms109', 
       'outflow_ms122', 'rain_mm18', 'outflow_ms18', 'year','whos']]
df3
# Out:
#    water_year  rain_mm109  outflow_ms109  outflow_ms122  rain_mm18  \
# 0     1980/81        1182           5408           7248        174
# 1     1981/82        1098           5112           7316        242
# 2     1982/83        1156           5701           8567        124
# 3     1983/84         993           4265           8905        141
# 4     1984/85        1182           5364           5813        343
# 5     1985/86        1027           4991           7951        229
# 6     1986/87        1151           5196           7593        267
# 7     1987/88        1210           5572           8456        294
# 8     1988/89         976           4330           6465        200
# 9     1989/90        1130           4973          10520        209
# 10    1990/91        1022           4418           7120        216
# 11    1991/92        1151           4506           5493        280
# 12    1992/93        1130           5246           8751        219
# ...

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
df3.to_excel('df3.xlsx')

# %%
df3.sort_values(by="rain_mm109")
# Out:
#    water_year  rain_mm109  outflow_ms109  outflow_ms122  rain_mm18  \
# 15    1995/96         856           3479           5515        172
# 8     1988/89         976           4330           6465        200
# 3     1983/84         993           4265           8905        141
# 22    2002/03        1021           4366           7093        176
# 10    1990/91        1022           4418           7120        216
# 5     1985/86        1027           4991           7951        229
# 25    2005/06        1046           4059           4578        188
# 16    1996/97        1047           4019           5770        256
# 30    2010/11        1053           4521           6593        267
# 32    2012/13        1090           5329           9615        187
# 24    2004/05        1095           4547           7183        217
# 1     1981/82        1098           5112           7316        242
# 29    2009/10        1103           4738           6435        244
# ...

# %%
df3.loc[3:6,['water_year', 'rain_mm109', 'outflow_ms109']]
# Out:
#   water_year  rain_mm109  outflow_ms109
# 3    1983/84         993           4265
# 4    1984/85        1182           5364
# 5    1985/86        1027           4991
# 6    1986/87        1151           5196

# %%
df3.iloc[3,3]
# Out:
# 8905

# %%
df3.loc[3,"outflow_ms122"]
# Out:
# 8905

# %%
df3.append(df2,ignore_index=True)
# Out:
#     outflow_ms109  outflow_ms122  outflow_ms18  rain_mm109  rain_mm122  \
# 0            5408           7248          2212        1182         NaN
# 1            5112           7316          1936        1098         NaN
# 2            5701           8567          1802        1156         NaN
# 3            4265           8905          1078         993         NaN
# 4            5364           5813          4313        1182         NaN
# 5            4991           7951          2595        1027         NaN
# 6            5196           7593          2826        1151         NaN
# 7            5572           8456          3154        1210         NaN
# 8            4330           6465          1440         976         NaN
# 9            4973          10520          1740        1130         NaN
# 10           4418           7120          1923        1022         NaN
# 11           4506           5493          2118        1151         NaN
# ...

# %%
srs=pd.Series(np.random.randn(100),index=np.arange(100))
type(srs)
# Out:
# pandas.core.series.Series

# %%
srs.cumsum()
# Out:
# 0    -1.661846
# 1    -0.877402
# 2    -0.305775
# 3    -0.238038
# 4    -0.711522
# 5    -1.559026
# 6    -0.719661
# 7     0.054109
# 8     0.433838
# 9     1.156334
# 10    2.327243
# 11    0.805925
# 12    0.131251
# 13    1.182383
# 14    0.743535
# 15    0.129782
# 16    0.418597
# 17    1.229116
# 18    1.629913
# 19    2.052931
# 20    1.781315
# 21    3.178245
# 22    3.732277
# 23    4.226169
# 24    2.709013
# 25    2.704687
# 26    1.972754
# 27    2.145901
# 28    2.926444
# 29    2.636561
#         ...
# 70   -0.485679
# 71   -0.305249
# 72   -0.236148
# 73    0.846334
# 74   -0.712873
# 75   -1.130432
# 76   -0.425432
# 77    0.853679
# 78   -0.445545
# 79   -0.200414
# 80   -2.608703
# 81   -1.804901
# 82   -1.602194
# 83   -1.401909
# 84   -2.691489
# 85   -2.325627
# 86   -2.605866
# 87   -2.910796
# 88   -2.553863
# 89   -1.494798
# 90   -0.961705
# 91   -2.560675
# 92   -2.121504
# 93   -2.989476
# 94   -2.945344
# 95   -4.522669
# 96   -4.655794
# 97   -4.158264
# ...

# %%
srs.plot()
plt.show()

# %%
data = pd.DataFrame(
    np.random.rand(1000,4),
    index=np.arange(1000),
    columns=list("ABCD")
    )
data.cumsum()
plt.show()
