# %%
import numpy as np

# %%
from skimage import data,io

# %%
from skimage import exposure,img_as_float

# %%
from skimage import filters

# %%
from skimage import data, color,draw,transform,feature,util

# %%
import skimage.morphology as sm

# %%
import matplotlib.pyplot as plt

# %%
img = data.chelsea()

# %%
io.imshow(img)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
print(img.shape)
# Out:
# (300, 451, 3)

# %%
R=img[:,:,0]

# %%
io.imshow(R)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
io.imshow(img[:,:,1])
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
io.imshow(img[:,:,2])
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img_c=img[200:250,300:400,1]

# %%
io.imshow(img_c)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img[200,300,:]
# Out:
# array([124,  81,  39], dtype=uint8)

# %%
img[200,300,1]
# Out:
# 81

# %%
img_gray=color.rgb2gray(img)

# %%
io.imshow(img_gray)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img_gray
# Out:
# array([[0.48523098, 0.48523098, 0.47738784, ..., 0.11692392, 0.11692392,
#         0.11692392],
#        [0.49699569, 0.49307412, 0.48523098, ..., 0.12336824, 0.1225349 ,
#         0.1272898 ],
#        [0.50849255, 0.50457098, 0.49475569, ..., 0.12336039, 0.12728196,
#         0.13120353],
#        ...,
#        [0.24786745, 0.29884784, 0.40501294, ..., 0.58914824, 0.58914824,
#         0.58914824],
#        [0.38173647, 0.42487373, 0.39628392, ..., 0.57403529, 0.57403529,
#         0.57795686],
#        [0.42487373, 0.36883294, 0.36042431, ..., 0.55442745, 0.55442745,
#         0.55834902]])

# %%
rows,cols=img_gray.shape

# %%
for i in range(rows):
    for j in range(cols):
        if img_gray[i,j]>0.5:
            img_gray[i,j]=1
        else:
            img_gray[i,j]=0

# %%
io.imshow(img_gray)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img=io.imread(r"C:\Users\DELL\testing and learning\test.jpg")

# %%
img_float=img_as_float(img)

# %%
img_float
# Out:
# array([[[0.56078431, 0.47058824, 0.40784314],
#         [0.56078431, 0.47058824, 0.40784314],
#         [0.55294118, 0.4627451 , 0.4       ],
#         ...,
#         [0.17647059, 0.10588235, 0.05098039],
#         [0.17647059, 0.10588235, 0.05098039],
#         [0.17647059, 0.10588235, 0.05098039]],
#
#        [[0.57254902, 0.48235294, 0.41960784],
#         [0.56862745, 0.47843137, 0.41568627],
#         [0.56078431, 0.47058824, 0.40784314],
#         ...,
#         [0.18039216, 0.11372549, 0.05098039],
#         [0.17647059, 0.11372549, 0.05098039],
#         [0.18431373, 0.11764706, 0.05490196]],
#
#        [[0.58039216, 0.49411765, 0.43921569],
#         [0.57647059, 0.49019608, 0.43529412],
#         [0.57254902, 0.47843137, 0.42745098],
#         ...,
#         [0.18823529, 0.10980392, 0.06666667],
#         [0.19215686, 0.11372549, 0.07058824],
#         [0.19607843, 0.11764706, 0.0745098 ]],
#
#        ...,
#
#        [[0.36078431, 0.22745098, 0.11764706],
# ...

# %%
img5=img_as_float(data.moon())

# %%
gam1=exposure.adjust_gamma(img5,2)

# %%
log1=exposure.adjust_log(img5,0.7)

# %%
plt.subplot(1,3,1)
plt.imshow(img5)
plt.subplot(1,3,2)
plt.imshow(gam1)
plt.subplot(1,3,3)
plt.imshow(log1)

# %%
gam2=exposure.adjust_gamma(img5,0.2)
gam3=exposure.adjust_gamma(img5,0.5)
gam4=exposure.adjust_gamma(img5,0.8)
gam5=exposure.adjust_gamma(img5,1.6)
plt.subplot(1,4,1)
plt.imshow(gam2)
plt.subplot(1,4,2)
plt.imshow(gam3)
plt.subplot(1,4,3)
plt.imshow(gam4)
plt.subplot(1,4,4)
plt.imshow(gam5)

# %%
gam2=exposure.adjust_log(img5,0.002)
gam3=exposure.adjust_log(img5,0.7)
gam4=exposure.adjust_log(img5,1)
gam5=exposure.adjust_log(img5,56)
plt.subplot(1,4,1)
plt.imshow(gam2,plt.cm.gray)
plt.subplot(1,4,2)
plt.imshow(gam3)
plt.subplot(1,4,3)
plt.imshow(gam4)
plt.subplot(1,4,4)
plt.imshow(img5)

# %%
plt.figure("hist",figsize=(8,8))

# %%
arr=img5.flatten()

# %%
arr
# Out:
# array([0.45490196, 0.45490196, 0.47843137, ..., 0.4627451 , 0.4627451 ,
#        0.4627451 ])

# %%
img5
# Out:
# array([[0.45490196, 0.45490196, 0.47843137, ..., 0.36470588, 0.37647059,
#         0.37647059],
#        [0.45490196, 0.45490196, 0.47843137, ..., 0.36470588, 0.37647059,
#         0.37647059],
#        [0.45490196, 0.45490196, 0.47843137, ..., 0.36470588, 0.37647059,
#         0.37647059],
#        ...,
#        [0.42745098, 0.42745098, 0.43921569, ..., 0.45882353, 0.45490196,
#         0.45490196],
#        [0.44705882, 0.44705882, 0.44313725, ..., 0.4627451 , 0.4627451 ,
#         0.4627451 ],
#        [0.44705882, 0.44705882, 0.44313725, ..., 0.4627451 , 0.4627451 ,
#         0.4627451 ]])

# %%
img_c=exposure.equalize_hist(img5)

# %%
arr_c=img_c.flatten()

# %%
plt.subplot(2,2,1)
plt.imshow(img5,plt.cm.gray)
plt.subplot(2,2,2)
plt.hist(arr, bins=256, normed=False, edgecolor='None',facecolor='red')
plt.subplot(2,2,3)
plt.imshow(img_c,plt.cm.gray)
plt.subplot(2,2,4)
plt.hist(arr_c, bins=256, normed=False, edgecolor='None',facecolor='red')
plt.show()
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
img7=data.camera()

# %%
img_edge=filters.median(img7,sm.disk(5))
img_edge2=filters.median(img7,sm.disk(2))

# %%
plt.subplot(1,3,1)
plt.imshow(img7,plt.cm.gray)
plt.subplot(1,3,2)
plt.imshow(img_edge,plt.cm.gray)
plt.subplot(1,3,3)
plt.imshow(img_edge2,plt.cm.gray)

# %%
io.imshow(img)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img2=color.rgb2gray(img)

# %%
io.imshow(img2)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img2_edge=filters.sobel(img2)

# %%
plt.figure("img2",figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(img2,plt.cm.gray)
plt.subplot(1,2,2)
plt.imshow(img2_edge,plt.cm.gray)

# %%
thresh=filters.threshold_otsu(img2)

# %%
img_dst=(img2<=thresh)*3

# %%
img_dst=(img2<=(thresh*1))*1
plt.figure("img2",figsize=(16,16))
plt.subplot(1,2,1)
plt.imshow(img2,plt.cm.gray)
plt.subplot(1,2,2)
plt.imshow(img_dst,plt.cm.gray)

# %%
img_board=data.checkerboard()

# %%
io.imshow(img_board)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
img_dlt1=sm.dilation(img_board,sm.square(5))

# %%
img_dlt2=sm.dilation(img_board,sm.square(20))

# %%
plt.figure("img_board",figsize=(14,14))
plt.subplot(1,3,1)
plt.imshow(img_board,plt.cm.gray)
plt.subplot(1,3,2)
plt.imshow(img_dlt1,plt.cm.gray)
plt.subplot(1,3,3)
plt.imshow(img_dlt2,plt.cm.gray)

# %%
img_ers1=sm.erosion(img_board,sm.square(5))

# %%
img_ers2=sm.erosion(img_board,sm.square(20))

# %%
plt.figure("img_board",figsize=(14,14))
plt.subplot(1,3,1)
plt.imshow(img_board,plt.cm.gray)
plt.subplot(1,3,2)
plt.imshow(img_ers1,plt.cm.gray)
plt.subplot(1,3,3)
plt.imshow(img_ers2,plt.cm.gray)

# %%
io.imshow(data.coins())
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
data.coins().shape
# Out:
# (303, 384)

# %%
img_coins=data.coins()[0:95,70:370]

# %%
img_coins
# Out:
# array([[132, 136, 135, ..., 103, 103, 104],
#        [131, 133, 134, ..., 104, 103, 103],
#        [134, 133, 134, ..., 103, 102, 101],
#        ...,
#        [ 95,  93,  95, ...,  60,  57,  61],
#        [ 94,  92,  94, ...,  59,  56,  61],
#        [ 94,  92,  95, ...,  61,  57,  63]], dtype=uint8)

# %%
img_coins=util.img_as_ubyte(img_coins)

# %%
edges=feature.canny(img_coins,sigma=3,low_threshold=10,high_threshold=50)

# %%
fig,(ax0,ax1)=plt.subplots(1,2,figsize=(8,5))
ax0.imshow(edges,cmap=plt.cm.gray)
ax0.set_title("original image")
# Out:
# Text(0.5,1,'original image')

# %%
hough_radii=np.arange(15,30,2)
hough_res=transform.hough_circle(edges,hough_radii)

# %%
hough_res.shape
# Out:
# (8, 95, 300)

# %%
centers=[]
accums=[]
radii=[]

# %%
for radius,h in zip(hough_radii,hough_res):
    num_peaks=2
    peaks=feature.peak_local_max(h,num_peaks=num_peaks)
    centers.extend(peaks)
    accums.extend(h[peaks[:,0],peaks[:,1]])
    radii.extend([radius*num_peaks])

# %%
image_coins=color.gray2rgb(img_coins)
for idx in np.argsort(accums)[::-1][:5]:
    center_x, center_y = centers[idx]
    radius =radii[idx]
    cx,cy =draw.circle_perimeter(center_x,center_y,radius)
    image_coins[cx,cy]=(255,0,0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-300-7242132b5d7e> in <module>()
#       4     radius =radii[idx]
#       5     cx,cy =draw.circle_perimeter(center_x,center_y,radius)
# ----> 6     image_coins[cx,cy]=(255,0,0)
#
# IndexError: index 98 is out of bounds for axis 0 with size 95

# %%
image.shape
# Out:
# (95, 300, 3)

# %%
image_coins.shape
# Out:
# (95, 300, 3)

# %%
io.imshow(image)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
image = util.img_as_ubyte(data.coins()[0:95, 70:370]) #裁剪原图片
edges =feature.canny(image, sigma=3, low_threshold=10, high_threshold=50) #检测canny边缘
 
fig, (ax0,ax1) = plt.subplots(1,2, figsize=(8, 5))
 
ax0.imshow(edges, cmap=plt.cm.gray)  #显示canny边缘
ax0.set_title('original iamge')
 
hough_radii = np.arange(15, 30, 2)  #半径范围
hough_res =transform.hough_circle(edges, hough_radii)  #圆变换 
 
centers = []  #保存中心点坐标
accums = []   #累积值
radii = []    #半径
 
for radius, h in zip(hough_radii, hough_res):
    #每一个半径值，取出其中两个圆
    num_peaks = 2
    peaks =feature.peak_local_max(h, num_peaks=num_peaks) #取出峰值
    centers.extend(peaks)
    accums.extend(h[peaks[:, 0], peaks[:, 1]])
    radii.extend([radius] * num_peaks)
 
#画出最接近的5个圆
image = color.gray2rgb(image)
for idx in np.argsort(accums)[::-1][:5]:
    center_x, center_y = centers[idx]
    radius = radii[idx]
    cx, cy =draw.circle_perimeter(center_y, center_x, radius)
    image[cy, cx] = (255,0,0)
